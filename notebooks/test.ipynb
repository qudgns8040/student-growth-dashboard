# %%
from datetime import datetime
from zoneinfo import ZoneInfo


KST = ZoneInfo("Asia/Seoul")

now = datetime.now(KST)

print(now)
# Out:
# 2026-08-05 02:22:34.558827+09:00
