# %%
import pandas as pd

students = pd.read_csv("../data/students.csv")
dt_scores = pd.read_csv("../data/dt_scores.csv")

# %%
print("===== students.head() =====")
print(students.head())

print("\n")

print("===== dt_scores.head() =====")
print(dt_scores.head())

print("\n")

print("===== students.info() =====")
students.info()

print("\n")

print("===== dt_scores.info() =====")
dt_scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  20 non-null     object
#  1   name        20 non-null     object
#  2   age         20 non-null     object
#  3   class       20 non-null     object
# dtypes: object(4)
# memory usage: 768.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   student_id  1200 non-null   object
#  1   date        1200 non-null   object
#  2   dt_type     1200 non-null   object
#  3   score       1200 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 37.6+ KB
